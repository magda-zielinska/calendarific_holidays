# %% [markdown]
# # Working with Calendarific API - https://calendarific.com/
#
#
# ## From the holiday API extract the following information for every country and year 2021:
#
#     - country name
#     - holiday name
#     - date
#     - type of obsevance
#
#
#  # Holiday Api gives the following response:
#
#     {
#     "meta": {
#         "code": 200
#     },
#     "response": {
#         "holidays": [
#             {
#                 "name": "Name of holiday goes here",
#                 "description": "Description of holiday goes here",
#                 "date": {
#                     "iso": "2018-12-31",
#                     "datetime": {
#                         "year": 2018,
#                         "month": 12,
#                         "day": 31
#                     }
#                 },
#                 "type": [
#                     "Type of Observance goes here"
#                     ]
#                 }
#             ]
#         }
#     }

# %%
import json
import requests
import ijson
import os
import psycopg2

# %%
country_codes = []

# %%
with open('country_list.json', 'r') as file:
    countries = json.load(file)
    for country in countries:
        country_codes.append(country['code'])

# %%
country_codes
# Out:
# ['AF',
#  'AL',
#  'DZ',
#  'AS',
#  'AD',
#  'AO',
#  'AI',
#  'AG',
#  'AR',
#  'AM',
#  'AW',
#  'AU',
#  'AT',
#  'AZ',
#  'BH',
#  'BD',
#  'BB',
#  'BY',
#  'BE',
#  'BZ',
#  'BJ',
#  'BM',
#  'BT',
#  'BO',
#  'BA',
#  'BW',
#  'BR',
#  'VG',
#  'BN',
#  'BG',
#  'BF',
#  'BI',
#  'CV',
#  'KH',
#  'CM',
#  'CA',
#  'KY',
#  'CF',
#  'TD',
#  'CL',
#  'CN',
#  'CO',
#  'KM',
#  'CG',
#  'CD',
#  'CK',
#  'CR',
#  'CI',
#  'HR',
#  'CU',
#  'CW',
#  'CY',
#  'CZ',
#  'DK',
#  'DJ',
#  'DM',
#  'DO',
#  'TL',
#  'EC',
#  'EG',
#  'SV',
#  'GQ',
#  'ER',
#  'EE',
#  'ET',
#  'FK',
#  'FO',
#  'FJ',
#  'FI',
#  'FR',
#  'PF',
#  'GA',
#  'GM',
#  'GE',
#  'DE',
#  'GH',
#  'GI',
#  'GR',
#  'GL',
#  'GD',
#  'GU',
#  'GT',
#  'GG',
#  'GN',
#  'GW',
#  'GY',
#  'HT',
#  'HN',
#  'HK',
#  'HU',
#  'IS',
#  'IN',
#  'ID',
#  'IR',
#  'IQ',
#  'IE',
#  'IM',
#  'IL',
#  'IT',
#  'JM',
#  'JP',
#  'JE',
#  'JO',
#  'KZ',
#  'KE',
#  'KI',
#  'XK',
#  'KW',
#  'KG',
#  'LA',
#  'LV',
#  'LB',
#  'LS',
#  'LR',
#  'LY',
#  'LI',
#  'LT',
#  'LU',
#  'MO',
#  'MG',
#  'MW',
#  'MY',
#  'MV',
#  'ML',
#  'MT',
#  'MH',
#  'MQ',
#  'MR',
#  'MU',
#  'YT',
#  'MX',
#  'FM',
#  'MD',
#  'MC',
#  'MN',
#  'ME',
#  'MS',
#  'MA',
#  'MZ',
#  'MM',
#  'NA',
#  'NR',
#  'NP',
#  'NL',
#  'NC',
#  'NZ',
#  'NI',
#  'NE',
#  'NG',
#  'KP',
#  'MK',
#  'MP',
#  'NO',
#  'OM',
#  'PK',
#  'PW',
#  'PA',
#  'PG',
#  'PY',
#  'PE',
#  'PH',
#  'PL',
#  'PT',
#  'PR',
#  'QA',
#  'RE',
#  'RO',
#  'RU',
#  'RW',
#  'SH',
#  'KN',
#  'LC',
#  'MF',
#  'PM',
#  'VC',
#  'WS',
#  'SM',
#  'ST',
#  'SA',
#  'SN',
#  'RS',
#  'SC',
#  'SL',
#  'SG',
#  'SX',
#  'SK',
#  'SI',
#  'SB',
#  'SO',
#  'ZA',
#  'KR',
#  'SS',
#  'ES',
#  'LK',
#  'BL',
#  'SD',
#  'SR',
#  'SE',
#  'CH',
#  'SY',
#  'TW',
#  'TJ',
#  'TZ',
#  'TH',
#  'BS',
#  'TG',
#  'TO',
#  'TT',
#  'TN',
#  'TR',
#  'TM',
#  'TC',
#  'TV',
#  'VI',
#  'UG',
#  'UA',
#  'AE',
#  'GB',
#  'US',
#  'UY',
#  'UZ',
#  'VU',
#  'VA',
#  'VE',
#  'VN',
#  'WF',
#  'YE',
#  'ZM',
#  'ZW',
#  'SZ']

# %%
# country_name
# holiday_name
# holiday_date
# type_observance


def load_holidays():
    
    """
    Function to save all responses of the holidays from the Calendarific API
    for all countries which country codes from the variable country_codes above
    for year 2021
    
    returns: a list with all responses
    
    """
    
    API_KEY = os.environ.get('API_KEY_CALENDARIFIC')
    # API_URL = f'https://calendarific.com/api/v2/holidays?&api_key={API_KEY}&country={country_code}&year=2021'
    holiday_responses = []
    for code in country_codes:
        response = requests.get(f'https://calendarific.com/api/v2/holidays?&api_key={API_KEY}&country={code}&year=2021')
        holiday_responses.append(json.loads(response.text))
    return holiday_responses

def choose_info_holidays(holiday_response):
    
    """
    Function to save extracted information from holiday responses
    
    
    returns: a list of dictionaries - 
                        key: name of the country
                        values: holidays
    
    """
    
    
    dict_holidays = {}
    for response in holiday_response:
        list_holiday = []
        
        for holiday in response['response']['holidays']:
            holiday_info = {
                'holiday_name' : holiday['name'],
                'holiday_date' : holiday['date']['iso'],
                'type_observance' : holiday['type'][0]
            }
            list_holiday.append(holiday_info)
        dict_holidays[holiday['country']['name']] = list_holiday
        
    return dict_holidays

# %%
holiday_response = load_holidays()

# %%
holidays_in_country = choose_info_holidays(holiday_response)

# %%
with open('saved_holidays.json','w') as holiday_file:
    json.dump(holidays_in_country, holiday_file)

# %%
with open('saved_holidays.json', 'r') as saved_file:
    saved = json.load(saved_file)

# %%
saved
# Out:
# {'Afghanistan': [{'holiday_name': 'March Equinox',
#    'holiday_date': '2021-03-20T14:07:30+04:30',
#    'type_observance': 'Season'},
#   {'holiday_name': 'Ramadan starts',
#    'holiday_date': '2021-04-13',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Afghan Victory Day',
#    'holiday_date': '2021-04-28',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Eid al-Fitr',
#    'holiday_date': '2021-05-13',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Eid al-Fitr Holiday',
#    'holiday_date': '2021-05-14',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Eid al-Fitr Holiday',
#    'holiday_date': '2021-05-15',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'June Solstice',
#    'holiday_date': '2021-06-21T08:02:08+04:30',
#    'type_observance': 'Season'},
#   {'holiday_name': 'Day of Arafat',
#    'holiday_date': '2021-07-19',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Eid al-Qurban',
#    'holiday_date': '2021-07-20',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Eid al-Qurban Holiday',
#    'holiday_date': '2021-07-21',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Eid al-Qurban Holiday',
#    'holiday_date': '2021-07-22',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Independence Day (National Day)',
#    'holiday_date': '2021-08-19',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Ashura',
#    'holiday_date': '2021-08-19',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Martyrs and Ahmad Shah Masoud Day',
#    'holiday_date': '2021-09-09',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'September Equinox',
#    'holiday_date': '2021-09-22T23:51:10+04:30',
#    'type_observance': 'Season'},
#   {'holiday_name': "The Prophet's Birthday",
#    'holiday_date': '2021-10-19',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'December Solstice',
#    'holiday_date': '2021-12-21T20:29:17+04:30',
#    'type_observance': 'Season'}],
#  'Albania': [{'holiday_name': "New Year's Day",
#    'holiday_date': '2021-01-01',
#    'type_observance': 'National holiday'},
#   {'holiday_name': "New Year's Day (Day 2)",
#    'holiday_date': '2021-01-02',
#    'type_observance': 'National holiday'},
#   {'holiday_name': "Day off for New Year's Day (Day 2)",
#    'holiday_date': '2021-01-04',
#    'type_observance': 'National holiday'},
#   {'holiday_name': "Valentine's Day",
#    'holiday_date': '2021-02-14',
#    'type_observance': 'Observance'},
#   {'holiday_name': "Mothers' Day",
#    'holiday_date': '2021-03-08',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'Summer Day',
#    'holiday_date': '2021-03-14',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Day off for Summer Day',
#    'holiday_date': '2021-03-15',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'March Equinox',
#    'holiday_date': '2021-03-20T10:37:30+01:00',
#    'type_observance': 'Season'},
#   {'holiday_name': 'Nevruz Day',
#    'holiday_date': '2021-03-22',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Daylight Saving Time starts',
#    'holiday_date': '2021-03-28T02:00:00+01:00',
#    'type_observance': 'Clock change/Daylight Saving Time'},
#   {'holiday_name': 'Good Friday',
#    'holiday_date': '2021-04-02',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'Holy Saturday',
#    'holiday_date': '2021-04-03',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'Easter Sunday',
#    'holiday_date': '2021-04-04',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Easter Monday',
#    'holiday_date': '2021-04-05',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'Good Friday (Orthodox)',
#    'holiday_date': '2021-04-30',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'Easter Saturday (Orthodox)',
#    'holiday_date': '2021-05-01',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'International Worker’s Day',
#    'holiday_date': '2021-05-01',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Easter Sunday (Orthodox)',
#    'holiday_date': '2021-05-02',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Easter Monday (Orthodox)',
#    'holiday_date': '2021-05-03',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'Eid al-Fitr',
#    'holiday_date': '2021-05-13',
#    'type_observance': 'National holiday'},
#   {'holiday_name': "Fathers' Day",
#    'holiday_date': '2021-06-20',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'June Solstice',
#    'holiday_date': '2021-06-21T05:32:08+02:00',
#    'type_observance': 'Season'},
#   {'holiday_name': 'Feast of the Sacrifice',
#    'holiday_date': '2021-07-20',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Mother Teresa Beatification Day',
#    'holiday_date': '2021-09-05',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'September Equinox',
#    'holiday_date': '2021-09-22T21:21:10+02:00',
#    'type_observance': 'Season'},
#   {'holiday_name': 'Daylight Saving Time ends',
#    'holiday_date': '2021-10-31T03:00:00+02:00',
#    'type_observance': 'Clock change/Daylight Saving Time'},
#   {'holiday_name': 'Halloween',
#    'holiday_date': '2021-10-31',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'Flag and Independence Day',
#    'holiday_date': '2021-11-28',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Liberation Day',
#    'holiday_date': '2021-11-29',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'National Youth Day',
#    'holiday_date': '2021-12-08',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'December Solstice',
#    'holiday_date': '2021-12-21T16:59:17+01:00',
#    'type_observance': 'Season'},
#   {'holiday_name': 'Christmas Eve',
#    'holiday_date': '2021-12-24',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'Christmas Day',
#    'holiday_date': '2021-12-25',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Day off for Christmas Day',
#    'holiday_date': '2021-12-27',
#    'type_observance': 'National holiday'},
#   {'holiday_name': "New Year's Eve",
#    'holiday_date': '2021-12-31',
#    'type_observance': 'Observance'}],
#  'Algeria': [{'holiday_name': 'New Year',
#    'holiday_date': '2021-01-01',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Berber New Year',
#    'holiday_date': '2021-01-12',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'March Equinox',
#    'holiday_date': '2021-03-20T10:37:30+01:00',
#    'type_observance': 'Season'},
#   {'holiday_name': 'May Day',
#    'holiday_date': '2021-05-01',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Eid al-Fitr',
#    'holiday_date': '2021-05-13',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Eid al-Fitr Holiday',
#    'holiday_date': '2021-05-14',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'June Solstice',
#    'holiday_date': '2021-06-21T04:32:08+01:00',
#    'type_observance': 'Season'},
#   {'holiday_name': 'Independence Day',
#    'holiday_date': '2021-07-05',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Eid al-Adha',
#    'holiday_date': '2021-07-20',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Eid al-Adha Holiday',
#    'holiday_date': '2021-07-21',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Muharram',
#    'holiday_date': '2021-08-10',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Day of Achura',
#    'holiday_date': '2021-08-19',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'September Equinox',
#    'holiday_date': '2021-09-22T20:21:10+01:00',
#    'type_observance': 'Season'},
#   {'holiday_name': "The Prophet's Birthday",
#    'holiday_date': '2021-10-19',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Anniversary of the Revolution',
#    'holiday_date': '2021-11-01',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'December Solstice',
#    'holiday_date': '2021-12-21T16:59:17+01:00',
#    'type_observance': 'Season'}],
#  'American Samoa': [{'holiday_name': "New Year's Day",
#    'holiday_date': '2021-01-01',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Martin Luther King Jr. Day',
#    'holiday_date': '2021-01-18',
#    'type_observance': 'National holiday'},
#   {'holiday_name': "President's Day",
#    'holiday_date': '2021-02-15',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'March Equinox',
#    'holiday_date': '2021-03-19T22:37:30-11:00',
#    'type_observance': 'Season'},
#   {'holiday_name': 'Good Friday',
#    'holiday_date': '2021-04-02',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Flag Day',
#    'holiday_date': '2021-04-17',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Memorial Day',
#    'holiday_date': '2021-05-31',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'June Solstice',
#    'holiday_date': '2021-06-20T16:32:08-11:00',
#    'type_observance': 'Season'},
#   {'holiday_name': 'Independence Day',
#    'holiday_date': '2021-07-04',
#    'type_observance': 'National holiday'},
#   {'holiday_name': "Manu'a Cession Day",
#    'holiday_date': '2021-07-16',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Labor Day',
#    'holiday_date': '2021-09-06',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'September Equinox',
#    'holiday_date': '2021-09-22T08:21:10-11:00',
#    'type_observance': 'Season'},
#   {'holiday_name': 'Columbus Day',
#    'holiday_date': '2021-10-11',
#    'type_observance': 'National holiday'},
#   {'holiday_name': "Veterans' Day",
#    'holiday_date': '2021-11-11',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Thanksgiving',
#    'holiday_date': '2021-11-25',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'December Solstice',
#    'holiday_date': '2021-12-21T04:59:17-11:00',
#    'type_observance': 'Season'},
#   {'holiday_name': 'Christmas Day',
#    'holiday_date': '2021-12-25',
#    'type_observance': 'National holiday'}],
#  'Andorra': [{'holiday_name': "New Year's Day",
#    'holiday_date': '2021-01-01',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Epiphany',
#    'holiday_date': '2021-01-06',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Carnival',
#    'holiday_date': '2021-02-15',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Constitution Day',
#    'holiday_date': '2021-03-14',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'March Equinox',
#    'holiday_date': '2021-03-20T10:37:30+01:00',
#    'type_observance': 'Season'},
#   {'holiday_name': 'Daylight Saving Time starts',
#    'holiday_date': '2021-03-28T02:00:00+01:00',
#    'type_observance': 'Clock change/Daylight Saving Time'},
#   {'holiday_name': 'Maundy Thursday',
#    'holiday_date': '2021-04-01',
#    'type_observance': 'Common local holiday'},
#   {'holiday_name': 'Good Friday',
#    'holiday_date': '2021-04-02',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Holy Saturday',
#    'holiday_date': '2021-04-03',
#    'type_observance': 'Common local holiday'},
#   {'holiday_name': 'Easter Sunday',
#    'holiday_date': '2021-04-04',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'Easter Monday',
#    'holiday_date': '2021-04-05',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'May Day',
#    'holiday_date': '2021-05-01',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Ascension Day',
#    'holiday_date': '2021-05-13',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'Whit Sunday',
#    'holiday_date': '2021-05-23',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'Whit Monday',
#    'holiday_date': '2021-05-24',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'June Solstice',
#    'holiday_date': '2021-06-21T05:32:08+02:00',
#    'type_observance': 'Season'},
#   {'holiday_name': 'Assumption of Mary',
#    'holiday_date': '2021-08-15',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'National Day',
#    'holiday_date': '2021-09-08',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'September Equinox',
#    'holiday_date': '2021-09-22T21:21:10+02:00',
#    'type_observance': 'Season'},
#   {'holiday_name': 'Daylight Saving Time ends',
#    'holiday_date': '2021-10-31T03:00:00+02:00',
#    'type_observance': 'Clock change/Daylight Saving Time'},
#   {'holiday_name': "All Saints' Day",
#    'holiday_date': '2021-11-01',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Feast of the Immaculate Conception',
#    'holiday_date': '2021-12-08',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'December Solstice',
#    'holiday_date': '2021-12-21T16:59:17+01:00',
#    'type_observance': 'Season'},
#   {'holiday_name': 'Christmas Eve',
#    'holiday_date': '2021-12-24',
#    'type_observance': 'Common local holiday'},
#   {'holiday_name': 'Christmas Day',
#    'holiday_date': '2021-12-25',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Boxing Day',
#    'holiday_date': '2021-12-26',
#    'type_observance': 'National holiday'},
#   {'holiday_name': "New Year's Eve (Bank holiday)",
#    'holiday_date': '2021-12-31',
#    'type_observance': 'Common local holiday'}],
#  'Angola': [{'holiday_name': 'New Year',
#    'holiday_date': '2021-01-01',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Liberation Movement Day',
#    'holiday_date': '2021-02-04',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Day off for Liberation Movement Day',
#    'holiday_date': '2021-02-05',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Carnival',
#    'holiday_date': '2021-02-16',
#    'type_observance': 'National holiday'},
#   {'holiday_name': "International Woman's Day",
#    'holiday_date': '2021-03-08',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'March Equinox',
#    'holiday_date': '2021-03-20T10:37:30+01:00',
#    'type_observance': 'Season'},
#   {'holiday_name': 'Day off for Southern Africa Liberation Day',
#    'holiday_date': '2021-03-22',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Southern Africa Liberation Day',
#    'holiday_date': '2021-03-23',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Good Friday',
#    'holiday_date': '2021-04-02',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Peace Day',
#    'holiday_date': '2021-04-04',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'May Day',
#    'holiday_date': '2021-05-01',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'June Solstice',
#    'holiday_date': '2021-06-21T04:32:08+01:00',
#    'type_observance': 'Season'},
#   {'holiday_name': 'National Hero Day',
#    'holiday_date': '2021-09-17',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'September Equinox',
#    'holiday_date': '2021-09-22T20:21:10+01:00',
#    'type_observance': 'Season'},
#   {'holiday_name': "Day off for All Souls' Day",
#    'holiday_date': '2021-11-01',
#    'type_observance': 'National holiday'},
#   {'holiday_name': "All Souls' Day",
#    'holiday_date': '2021-11-02',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Independence Day',
#    'holiday_date': '2021-11-11',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Day off for Independence Day',
#    'holiday_date': '2021-11-12',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'December Solstice',
#    'holiday_date': '2021-12-21T16:59:17+01:00',
#    'type_observance': 'Season'},
#   {'holiday_name': 'Christmas Day',
#    'holiday_date': '2021-12-25',
#    'type_observance': 'National holiday'}],
#  'Anguilla': [{'holiday_name': "New Year's Day",
#    'holiday_date': '2021-01-01',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'James Ronald Webster Day',
#    'holiday_date': '2021-03-02',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'March Equinox',
#    'holiday_date': '2021-03-20T05:37:30-04:00',
#    'type_observance': 'Season'},
#   {'holiday_name': 'Good Friday',
#    'holiday_date': '2021-04-02',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Easter Monday',
#    'holiday_date': '2021-04-05',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Labor Day / May Day',
#    'holiday_date': '2021-05-01',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Day off for Labor Day / May Day',
#    'holiday_date': '2021-05-03',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Whit Monday',
#    'holiday_date': '2021-05-24',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Anguilla Day',
#    'holiday_date': '2021-05-30',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Day off for Anguilla Day',
#    'holiday_date': '2021-05-31',
#    'type_observance': 'National holiday'},
#   {'holiday_name': "Sovereign's Birthday",
#    'holiday_date': '2021-06-14',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'June Solstice',
#    'holiday_date': '2021-06-20T23:32:08-04:00',
#    'type_observance': 'Season'},
#   {'holiday_name': 'August Monday',
#    'holiday_date': '2021-08-02',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'August Thursday',
#    'holiday_date': '2021-08-05',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Constitution Day',
#    'holiday_date': '2021-08-06',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'September Equinox',
#    'holiday_date': '2021-09-22T15:21:10-04:00',
#    'type_observance': 'Season'},
#   {'holiday_name': 'National Heroes and Heroines Day',
#    'holiday_date': '2021-12-19',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'December Solstice',
#    'holiday_date': '2021-12-21T11:59:17-04:00',
#    'type_observance': 'Season'},
#   {'holiday_name': 'Christmas Day',
#    'holiday_date': '2021-12-25',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Boxing Day',
#    'holiday_date': '2021-12-26',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Day off for Christmas Day',
#    'holiday_date': '2021-12-27',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Day off for Boxing Day',
#    'holiday_date': '2021-12-28',
#    'type_observance': 'National holiday'}],
#  'Antigua and Barbuda': [{'holiday_name': "New Year's Day",
#    'holiday_date': '2021-01-01',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'March Equinox',
#    'holiday_date': '2021-03-20T05:37:30-04:00',
#    'type_observance': 'Season'},
#   {'holiday_name': 'Good Friday',
#    'holiday_date': '2021-04-02',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Easter Monday',
#    'holiday_date': '2021-04-05',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Labour Day',
#    'holiday_date': '2021-05-03',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Whit Monday',
#    'holiday_date': '2021-05-24',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'June Solstice',
#    'holiday_date': '2021-06-20T23:32:08-04:00',
#    'type_observance': 'Season'},
#   {'holiday_name': 'Carnival Holiday',
#    'holiday_date': '2021-08-02',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Carnival Holiday',
#    'holiday_date': '2021-08-03',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'September Equinox',
#    'holiday_date': '2021-09-22T15:21:10-04:00',
#    'type_observance': 'Season'},
#   {'holiday_name': 'Independence Day',
#    'holiday_date': '2021-11-01',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'National Heroes Day',
#    'holiday_date': '2021-12-09',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'December Solstice',
#    'holiday_date': '2021-12-21T11:59:17-04:00',
#    'type_observance': 'Season'},
#   {'holiday_name': 'Christmas Day',
#    'holiday_date': '2021-12-25',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Boxing Day',
#    'holiday_date': '2021-12-26',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Christmas Day observed',
#    'holiday_date': '2021-12-27',
#    'type_observance': 'National holiday'}],
#  'Argentina': [{'holiday_name': "New Year's Day",
#    'holiday_date': '2021-01-01',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Carnival / Shrove Monday',
#    'holiday_date': '2021-02-15',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Carnival / Shrove Tuesday',
#    'holiday_date': '2021-02-16',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'March Equinox',
#    'holiday_date': '2021-03-20T06:37:30-03:00',
#    'type_observance': 'Season'},
#   {'holiday_name': 'Memorial Day',
#    'holiday_date': '2021-03-24',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Passover Eve',
#    'holiday_date': '2021-03-27',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'First day of Passover',
#    'holiday_date': '2021-03-28',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'Second Day of Passover',
#    'holiday_date': '2021-03-29',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'Maundy Thursday',
#    'holiday_date': '2021-04-01',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Good Friday',
#    'holiday_date': '2021-04-02',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Day of the Veterans',
#    'holiday_date': '2021-04-02',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Sixth Day of Passover',
#    'holiday_date': '2021-04-02',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'Seventh Day of Passover',
#    'holiday_date': '2021-04-03',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'Easter Sunday',
#    'holiday_date': '2021-04-04',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'Last day of Passover',
#    'holiday_date': '2021-04-04',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'Action Day for Tolerance and Respect between People',
#    'holiday_date': '2021-04-24',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'Labor Day / May Day',
#    'holiday_date': '2021-05-01',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'End of Ramadan',
#    'holiday_date': '2021-05-12',
#    'type_observance': 'Muslim'},
#   {'holiday_name': 'National Day/May 1810 Revolution',
#    'holiday_date': '2021-05-25',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Commemoration of General Don Martín Miguel de Güemes',
#    'holiday_date': '2021-06-17',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Flag Day',
#    'holiday_date': '2021-06-20',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'June Solstice',
#    'holiday_date': '2021-06-21T00:32:08-03:00',
#    'type_observance': 'Season'},
#   {'holiday_name': 'Independence day',
#    'holiday_date': '2021-07-09',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Eid al-Adha',
#    'holiday_date': '2021-07-20',
#    'type_observance': 'Muslim'},
#   {'holiday_name': 'Muharram/New Year',
#    'holiday_date': '2021-08-10',
#    'type_observance': 'Muslim'},
#   {'holiday_name': 'San Martín Day',
#    'holiday_date': '2021-08-16',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Rosh Hashana Eve',
#    'holiday_date': '2021-09-06',
#    'type_observance': 'Hebrew'},
#   {'holiday_name': 'Rosh Hashana',
#    'holiday_date': '2021-09-07',
#    'type_observance': 'Hebrew'},
#   {'holiday_name': 'Second day of Rosh Hashana',
#    'holiday_date': '2021-09-08',
#    'type_observance': 'Hebrew'},
#   {'holiday_name': 'Yom Kippur Eve',
#    'holiday_date': '2021-09-15',
#    'type_observance': 'Hebrew'},
#   {'holiday_name': 'Yom Kippur',
#    'holiday_date': '2021-09-16',
#    'type_observance': 'Hebrew'},
#   {'holiday_name': 'September Equinox',
#    'holiday_date': '2021-09-22T16:21:10-03:00',
#    'type_observance': 'Season'},
#   {'holiday_name': 'Day of respect for cultural diversity',
#    'holiday_date': '2021-10-11',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'National Sovereignty Day',
#    'holiday_date': '2021-11-22',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Feast of the Immaculate Conception',
#    'holiday_date': '2021-12-08',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'December Solstice',
#    'holiday_date': '2021-12-21T12:59:17-03:00',
#    'type_observance': 'Season'},
#   {'holiday_name': 'Christmas Day',
#    'holiday_date': '2021-12-25',
#    'type_observance': 'National holiday'},
#   {'holiday_name': "New Year's Eve",
#    'holiday_date': '2021-12-31',
#    'type_observance': 'Observance'}],
#  'Armenia': [{'holiday_name': "New Year's Day",
#    'holiday_date': '2021-01-01',
#    'type_observance': 'National holiday'},
#   {'holiday_name': "New Year's Day (Day 2)",
#    'holiday_date': '2021-01-02',
#    'type_observance': 'National holiday'},
#   {'holiday_name': "New Year's Day (Day 3)",
#    'holiday_date': '2021-01-03',
#    'type_observance': 'National holiday'},
#   {'holiday_name': "New Year's Day (Day 4)",
#    'holiday_date': '2021-01-04',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Christmas Eve',
#    'holiday_date': '2021-01-05',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Christmas Day',
#    'holiday_date': '2021-01-06',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Christmas Remembrance Day',
#    'holiday_date': '2021-01-07',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Army Day',
#    'holiday_date': '2021-01-28',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Feast of Saint Vartan',
#    'holiday_date': '2021-02-11',
#    'type_observance': 'Observance'},
#   {'holiday_name': "Valentine's Day",
#    'holiday_date': '2021-02-14',
#    'type_observance': 'Observance'},
#   {'holiday_name': "International Women's Day",
#    'holiday_date': '2021-03-08',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'March Equinox',
#    'holiday_date': '2021-03-20T13:37:30+04:00',
#    'type_observance': 'Season'},
#   {'holiday_name': 'Good Friday',
#    'holiday_date': '2021-04-02',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'Holy Saturday',
#    'holiday_date': '2021-04-03',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'Easter Sunday',
#    'holiday_date': '2021-04-04',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'Easter Monday',
#    'holiday_date': '2021-04-05',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'Motherhood and Beauty Day',
#    'holiday_date': '2021-04-07',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'Genocide Remembrance Day',
#    'holiday_date': '2021-04-24',
#    'type_observance': 'National holiday'},
#   {'holiday_name': "Citizens' Day",
#    'holiday_date': '2021-04-24',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Labour Day/May Day',
#    'holiday_date': '2021-05-01',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Yerkrapah Day',
#    'holiday_date': '2021-05-08',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'Victory and Peace Day',
#    'holiday_date': '2021-05-09',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Republic Day',
#    'holiday_date': '2021-05-28',
#    'type_observance': 'National holiday'},
#   {'holiday_name': "Children's Day",
#    'holiday_date': '2021-06-01',
#    'type_observance': 'Observance'},
#   {'holiday_name': "Fathers' Day",
#    'holiday_date': '2021-06-20',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'June Solstice',
#    'holiday_date': '2021-06-21T07:32:08+04:00',
#    'type_observance': 'Season'},
#   {'holiday_name': 'Constitution Day',
#    'holiday_date': '2021-07-05',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Day of State Symbols',
#    'holiday_date': '2021-07-05',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'Knowledge and Literature Day',
#    'holiday_date': '2021-09-01',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'Independence Day',
#    'holiday_date': '2021-09-21',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'September Equinox',
#    'holiday_date': '2021-09-22T23:21:10+04:00',
#    'type_observance': 'Season'},
#   {'holiday_name': "Translators' Day",
#    'holiday_date': '2021-10-09',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'Halloween',
#    'holiday_date': '2021-10-31',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'Spitak Remembrance Day',
#    'holiday_date': '2021-12-07',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'December Solstice',
#    'holiday_date': '2021-12-21T19:59:17+04:00',
#    'type_observance': 'Season'},
#   {'holiday_name': "New Year's Eve",
#    'holiday_date': '2021-12-31',
#    'type_observance': 'National holiday'}],
#  'Aruba': [{'holiday_name': "New Year's Day",
#    'holiday_date': '2021-01-01',
#    'type_observance': 'National holiday'},
#   {'holiday_name': "Betico Croes' Birthday",
#    'holiday_date': '2021-01-25',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Carnival Monday',
#    'holiday_date': '2021-02-15',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'National Anthem and Flag Day',
#    'holiday_date': '2021-03-18',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'March Equinox',
#    'holiday_date': '2021-03-20T05:37:30-04:00',
#    'type_observance': 'Season'},
#   {'holiday_name': 'Good Friday',
#    'holiday_date': '2021-04-02',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Easter Monday',
#    'holiday_date': '2021-04-05',
#    'type_observance': 'National holiday'},
#   {'holiday_name': "King's Day",
#    'holiday_date': '2021-04-27',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Labor Day',
#    'holiday_date': '2021-05-01',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Ascension Day',
#    'holiday_date': '2021-05-13',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'June Solstice',
#    'holiday_date': '2021-06-20T23:32:08-04:00',
#    'type_observance': 'Season'},
#   {'holiday_name': 'September Equinox',
#    'holiday_date': '2021-09-22T15:21:10-04:00',
#    'type_observance': 'Season'},
#   {'holiday_name': 'December Solstice',
#    'holiday_date': '2021-12-21T11:59:17-04:00',
#    'type_observance': 'Season'},
#   {'holiday_name': 'Christmas Day',
#    'holiday_date': '2021-12-25',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Boxing Day',
#    'holiday_date': '2021-12-26',
#    'type_observance': 'National holiday'}],
#  'Australia': [{'holiday_name': "New Year's Day",
#    'holiday_date': '2021-01-01',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Epiphany',
#    'holiday_date': '2021-01-06',
#    'type_observance': 'Christian'},
#   {'holiday_name': 'Orthodox Christmas Day',
#    'holiday_date': '2021-01-07',
#    'type_observance': 'Orthodox'},
#   {'holiday_name': 'Orthodox New Year',
#    'holiday_date': '2021-01-14',
#    'type_observance': 'Orthodox'},
#   {'holiday_name': 'Australia Day',
#    'holiday_date': '2021-01-26',
#    'type_observance': 'National holiday'},
#   {'holiday_name': "Tu B'Shevat (Arbor Day)",
#    'holiday_date': '2021-01-28',
#    'type_observance': 'Hebrew'},
#   {'holiday_name': 'Royal Hobart Regatta',
#    'holiday_date': '2021-02-08',
#    'type_observance': 'Local holiday'},
#   {'holiday_name': 'Chinese New Year',
#    'holiday_date': '2021-02-12',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'Chinese New Year',
#    'holiday_date': '2021-02-12',
#    'type_observance': 'Local holiday'},
#   {'holiday_name': 'Chinese New Year (Day 2)',
#    'holiday_date': '2021-02-13',
#    'type_observance': 'Local holiday'},
#   {'holiday_name': "Valentine's Day",
#    'holiday_date': '2021-02-14',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'Carnival / Shrove Tuesday',
#    'holiday_date': '2021-02-16',
#    'type_observance': 'Christian'},
#   {'holiday_name': 'Ash Wednesday',
#    'holiday_date': '2021-02-17',
#    'type_observance': 'Christian'},
#   {'holiday_name': 'Purim',
#    'holiday_date': '2021-02-26',
#    'type_observance': 'Hebrew'},
#   {'holiday_name': 'Labour Day',
#    'holiday_date': '2021-03-01',
#    'type_observance': 'Local holiday'},
#   {'holiday_name': 'Foundation Day',
#    'holiday_date': '2021-03-06',
#    'type_observance': 'Local holiday'},
#   {'holiday_name': 'Labour Day',
#    'holiday_date': '2021-03-08',
#    'type_observance': 'Local holiday'},
#   {'holiday_name': 'Eight Hours Day',
#    'holiday_date': '2021-03-08',
#    'type_observance': 'Local holiday'},
#   {'holiday_name': 'Adelaide Cup',
#    'holiday_date': '2021-03-08',
#    'type_observance': 'Local holiday'},
#   {'holiday_name': 'Canberra Day',
#    'holiday_date': '2021-03-08',
#    'type_observance': 'Local holiday'},
#   {'holiday_name': "Isra and Mi'raj",
#    'holiday_date': '2021-03-11',
#    'type_observance': 'Muslim'},
#   {'holiday_name': "St Patrick's Day",
#    'holiday_date': '2021-03-17',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'National Close the Gap Day',
#    'holiday_date': '2021-03-18',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'March Equinox',
#    'holiday_date': '2021-03-20T20:37:30+11:00',
#    'type_observance': 'Season'},
#   {'holiday_name': 'Harmony Day',
#    'holiday_date': '2021-03-21',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'Palm Sunday',
#    'holiday_date': '2021-03-28',
#    'type_observance': 'Christian'},
#   {'holiday_name': 'First day of Passover',
#    'holiday_date': '2021-03-28',
#    'type_observance': 'Hebrew'},
#   {'holiday_name': 'Maundy Thursday',
#    'holiday_date': '2021-04-01',
#    'type_observance': 'Christian'},
#   {'holiday_name': 'Good Friday',
#    'holiday_date': '2021-04-02',
#    'type_observance': 'Local holiday'},
#   {'holiday_name': 'Good Friday',
#    'holiday_date': '2021-04-02',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Daylight Saving Time ends',
#    'holiday_date': '2021-04-04T03:00:00+11:00',
#    'type_observance': 'Clock change/Daylight Saving Time'},
#   {'holiday_name': 'Holy Saturday',
#    'holiday_date': '2021-04-03',
#    'type_observance': 'Local holiday'},
#   {'holiday_name': 'Last day of Passover',
#    'holiday_date': '2021-04-04',
#    'type_observance': 'Hebrew'},
#   {'holiday_name': 'Easter Sunday',
#    'holiday_date': '2021-04-04',
#    'type_observance': 'Local holiday'},
#   {'holiday_name': 'Easter Sunday',
#    'holiday_date': '2021-04-04',
#    'type_observance': 'Local holiday'},
#   {'holiday_name': 'Easter Sunday',
#    'holiday_date': '2021-04-04',
#    'type_observance': 'Local holiday'},
#   {'holiday_name': 'Easter Sunday',
#    'holiday_date': '2021-04-04',
#    'type_observance': 'Local holiday'},
#   {'holiday_name': 'Easter Sunday',
#    'holiday_date': '2021-04-04',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'Easter Monday',
#    'holiday_date': '2021-04-05',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Self Determination Day',
#    'holiday_date': '2021-04-06',
#    'type_observance': 'Local holiday'},
#   {'holiday_name': 'Easter Tuesday',
#    'holiday_date': '2021-04-06',
#    'type_observance': 'Local holiday'},
#   {'holiday_name': 'Yom HaShoah',
#    'holiday_date': '2021-04-08',
#    'type_observance': 'Hebrew'},
#   {'holiday_name': 'Ramadan Start',
#    'holiday_date': '2021-04-13',
#    'type_observance': 'Muslim'},
#   {'holiday_name': 'Yom HaAtzmaut',
#    'holiday_date': '2021-04-15',
#    'type_observance': 'Hebrew'},
#   {'holiday_name': 'ANZAC Day',
#    'holiday_date': '2021-04-25',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'ANZAC Day Observed',
#    'holiday_date': '2021-04-25',
#    'type_observance': 'Local holiday'},
#   {'holiday_name': 'ANZAC Day Observed',
#    'holiday_date': '2021-04-26',
#    'type_observance': 'Local holiday'},
#   {'holiday_name': "Lag B'Omer",
#    'holiday_date': '2021-04-30',
#    'type_observance': 'Hebrew'},
#   {'holiday_name': 'Orthodox Good Friday',
#    'holiday_date': '2021-04-30',
#    'type_observance': 'Orthodox'},
#   {'holiday_name': 'Orthodox Holy Saturday',
#    'holiday_date': '2021-05-01',
#    'type_observance': 'Orthodox'},
#   {'holiday_name': 'Orthodox Easter',
#    'holiday_date': '2021-05-02',
#    'type_observance': 'Orthodox'},
#   {'holiday_name': 'Orthodox Easter Monday',
#    'holiday_date': '2021-05-03',
#    'type_observance': 'Orthodox'},
#   {'holiday_name': 'May Day',
#    'holiday_date': '2021-05-03',
#    'type_observance': 'Local holiday'},
#   {'holiday_name': 'Labour Day',
#    'holiday_date': '2021-05-03',
#    'type_observance': 'Local holiday'},
#   {'holiday_name': 'Laylatul Qadr (Night of Power)',
#    'holiday_date': '2021-05-08',
#    'type_observance': 'Muslim'},
#   {'holiday_name': "Mother's Day",
#    'holiday_date': '2021-05-09',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'Ascension Day',
#    'holiday_date': '2021-05-13',
#    'type_observance': 'Christian'},
#   {'holiday_name': 'Eid ul Fitr',
#    'holiday_date': '2021-05-13',
#    'type_observance': 'Muslim'},
#   {'holiday_name': 'Hari Raya Puasa',
#    'holiday_date': '2021-05-13',
#    'type_observance': 'Local holiday'},
#   {'holiday_name': 'Shavuot',
#    'holiday_date': '2021-05-17',
#    'type_observance': 'Hebrew'},
#   {'holiday_name': 'Pentecost',
#    'holiday_date': '2021-05-23',
#    'type_observance': 'Christian'},
#   {'holiday_name': 'Whit Monday',
#    'holiday_date': '2021-05-24',
#    'type_observance': 'Christian'},
#   {'holiday_name': 'National Sorry Day',
#    'holiday_date': '2021-05-26',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'Trinity Sunday',
#    'holiday_date': '2021-05-30',
#    'type_observance': 'Christian'},
#   {'holiday_name': 'Reconciliation Day',
#    'holiday_date': '2021-05-31',
#    'type_observance': 'Local holiday'},
#   {'holiday_name': 'Corpus Christi',
#    'holiday_date': '2021-06-03',
#    'type_observance': 'Christian'},
#   {'holiday_name': 'Queensland Day',
#    'holiday_date': '2021-06-06',
#    'type_observance': 'Local observance'},
#   {'holiday_name': 'Western Australia Day',
#    'holiday_date': '2021-06-07',
#    'type_observance': 'Common local holiday'},
#   {'holiday_name': 'Bounty Day',
#    'holiday_date': '2021-06-08',
#    'type_observance': 'Local holiday'},
#   {'holiday_name': "Queen's Birthday",
#    'holiday_date': '2021-06-14',
#    'type_observance': 'Local holiday'},
#   {'holiday_name': "Queen's Birthday",
#    'holiday_date': '2021-06-14',
#    'type_observance': 'Local holiday'},
#   {'holiday_name': 'June Solstice',
#    'holiday_date': '2021-06-21T13:32:08+10:00',
#    'type_observance': 'Season'},
#   {'holiday_name': 'First Day of NAIDOC Week',
#    'holiday_date': '2021-07-04',
#    'type_observance': 'Observance'},
#   {'holiday_name': "Tisha B'Av",
#    'holiday_date': '2021-07-18',
#    'type_observance': 'Hebrew'},
#   {'holiday_name': 'Hari Raya Haji',
#    'holiday_date': '2021-07-20',
#    'type_observance': 'Local holiday'},
#   {'holiday_name': 'New South Wales Bank Holiday',
#    'holiday_date': '2021-08-02',
#    'type_observance': 'Local holiday'},
#   {'holiday_name': 'Northern Territory Picnic Day',
#    'holiday_date': '2021-08-02',
#    'type_observance': 'Local holiday'},
#   {'holiday_name': 'Muharram/Islamic New Year',
#    'holiday_date': '2021-08-10',
#    'type_observance': 'Muslim'},
#   {'holiday_name': 'Royal National Agricultural Show Day Queensland',
#    'holiday_date': '2021-08-11',
#    'type_observance': 'Local holiday'},
#   {'holiday_name': 'Assumption of Mary',
#    'holiday_date': '2021-08-15',
#    'type_observance': 'Christian'},
#   {'holiday_name': "Father's Day",
#    'holiday_date': '2021-09-05',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'Rosh Hashana',
#    'holiday_date': '2021-09-07',
#    'type_observance': 'Hebrew'},
#   {'holiday_name': 'Yom Kippur',
#    'holiday_date': '2021-09-16',
#    'type_observance': 'Hebrew'},
#   {'holiday_name': 'First day of Sukkot',
#    'holiday_date': '2021-09-21',
#    'type_observance': 'Hebrew'},
#   {'holiday_name': 'September Equinox',
#    'holiday_date': '2021-09-23T05:21:10+10:00',
#    'type_observance': 'Season'},
#   {'holiday_name': 'Friday before the AFL Grand Final',
#    'holiday_date': '2021-09-24',
#    'type_observance': 'Local holiday'},
#   {'holiday_name': 'Hoshana Rabbah',
#    'holiday_date': '2021-09-27',
#    'type_observance': 'Hebrew'},
#   {'holiday_name': "Queen's Birthday",
#    'holiday_date': '2021-09-27',
#    'type_observance': 'Common local holiday'},
#   {'holiday_name': 'Shemini Atzeret',
#    'holiday_date': '2021-09-28',
#    'type_observance': 'Hebrew'},
#   {'holiday_name': 'Simchat Torah',
#    'holiday_date': '2021-09-29',
#    'type_observance': 'Hebrew'},
#   {'holiday_name': 'Daylight Saving Time starts',
#    'holiday_date': '2021-10-03T02:00:00+10:00',
#    'type_observance': 'Clock change/Daylight Saving Time'},
#   {'holiday_name': 'Feast of St Francis of Assisi',
#    'holiday_date': '2021-10-04',
#    'type_observance': 'Christian'},
#   {'holiday_name': 'Territory Day',
#    'holiday_date': '2021-10-04',
#    'type_observance': 'Local holiday'},
#   {'holiday_name': "Queen's Birthday",
#    'holiday_date': '2021-10-04',
#    'type_observance': 'Common local holiday'},
#   {'holiday_name': 'Labour Day',
#    'holiday_date': '2021-10-04',
#    'type_observance': 'Local holiday'},
#   {'holiday_name': 'Norfolk Island Agricultural Show Day',
#    'holiday_date': '2021-10-11',
#    'type_observance': 'Local holiday'},
#   {'holiday_name': 'Milad un Nabi (Mawlid)',
#    'holiday_date': '2021-10-19',
#    'type_observance': 'Muslim'},
#   {'holiday_name': 'Hari Maulad Nabi',
#    'holiday_date': '2021-10-19',
#    'type_observance': 'Local holiday'},
#   {'holiday_name': 'Halloween',
#    'holiday_date': '2021-10-31',
#    'type_observance': 'Observance'},
#   {'holiday_name': "All Saints' Day",
#    'holiday_date': '2021-11-01',
#    'type_observance': 'Christian'},
#   {'holiday_name': 'Recreation Day',
#    'holiday_date': '2021-11-01',
#    'type_observance': 'Local holiday'},
#   {'holiday_name': "All Souls' Day",
#    'holiday_date': '2021-11-02',
#    'type_observance': 'Christian'},
#   {'holiday_name': 'Melbourne Cup Day',
#    'holiday_date': '2021-11-02',
#    'type_observance': 'Local holiday'},
#   {'holiday_name': 'Remembrance Day',
#    'holiday_date': '2021-11-11',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'Thanksgiving Day',
#    'holiday_date': '2021-11-24',
#    'type_observance': 'Local holiday'},
#   {'holiday_name': 'First Sunday of Advent',
#    'holiday_date': '2021-11-28',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'First Day of Hanukkah',
#    'holiday_date': '2021-11-29',
#    'type_observance': 'Hebrew'},
#   {'holiday_name': 'Last day of Hanukkah',
#    'holiday_date': '2021-12-06',
#    'type_observance': 'Hebrew'},
#   {'holiday_name': 'Feast of the Immaculate Conception',
#    'holiday_date': '2021-12-08',
#    'type_observance': 'Christian'},
#   {'holiday_name': 'December Solstice',
#    'holiday_date': '2021-12-22T02:59:17+11:00',
#    'type_observance': 'Season'},
#   {'holiday_name': 'Christmas Eve',
#    'holiday_date': '2021-12-24',
#    'type_observance': 'Local holiday'},
#   {'holiday_name': 'Christmas Eve',
#    'holiday_date': '2021-12-24',
#    'type_observance': 'Local holiday'},
#   {'holiday_name': 'Christmas Eve',
#    'holiday_date': '2021-12-24',
#    'type_observance': 'Local holiday'},
#   {'holiday_name': 'Christmas Eve',
#    'holiday_date': '2021-12-24',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'Christmas Day',
#    'holiday_date': '2021-12-25',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Christmas Day',
#    'holiday_date': '2021-12-25',
#    'type_observance': 'Local holiday'},
#   {'holiday_name': 'Boxing Day',
#    'holiday_date': '2021-12-26',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Proclamation Day',
#    'holiday_date': '2021-12-26',
#    'type_observance': 'Local holiday'},
#   {'holiday_name': 'Christmas Day Observed',
#    'holiday_date': '2021-12-27',
#    'type_observance': 'Local holiday'},
#   {'holiday_name': 'Boxing Day Observed',
#    'holiday_date': '2021-12-28',
#    'type_observance': 'Local holiday'},
#   {'holiday_name': 'Day off for Proclamation Day',
#    'holiday_date': '2021-12-28',
#    'type_observance': 'Local holiday'},
#   {'holiday_name': "New Year's Eve",
#    'holiday_date': '2021-12-31',
#    'type_observance': 'Local holiday'},
#   {'holiday_name': "New Year's Eve",
#    'holiday_date': '2021-12-31',
#    'type_observance': 'Observance'},
#   {'holiday_name': "New Year's Eve",
#    'holiday_date': '2021-12-31',
#    'type_observance': 'Local holiday'}],
#  'Austria': [{'holiday_name': "New Year's Day",
#    'holiday_date': '2021-01-01',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Epiphany',
#    'holiday_date': '2021-01-06',
#    'type_observance': 'National holiday'},
#   {'holiday_name': "Saint Joseph's Day",
#    'holiday_date': '2021-03-19',
#    'type_observance': 'Local holiday'},
#   {'holiday_name': 'March Equinox',
#    'holiday_date': '2021-03-20T10:37:30+01:00',
#    'type_observance': 'Season'},
#   {'holiday_name': 'Palm Sunday',
#    'holiday_date': '2021-03-28',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'Daylight Saving Time starts',
#    'holiday_date': '2021-03-28T02:00:00+01:00',
#    'type_observance': 'Clock change/Daylight Saving Time'},
#   {'holiday_name': 'Good Friday',
#    'holiday_date': '2021-04-02',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'Easter Sunday',
#    'holiday_date': '2021-04-04',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'Easter Monday',
#    'holiday_date': '2021-04-05',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Labor Day / May Day',
#    'holiday_date': '2021-05-01',
#    'type_observance': 'National holiday'},
#   {'holiday_name': "Saint Florian's Day",
#    'holiday_date': '2021-05-04',
#    'type_observance': 'Local holiday'},
#   {'holiday_name': 'Ascension Day',
#    'holiday_date': '2021-05-13',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Whit Sunday',
#    'holiday_date': '2021-05-23',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'Whit Monday',
#    'holiday_date': '2021-05-24',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Corpus Christi',
#    'holiday_date': '2021-06-03',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'June Solstice',
#    'holiday_date': '2021-06-21T05:32:08+02:00',
#    'type_observance': 'Season'},
#   {'holiday_name': 'Assumption of Mary',
#    'holiday_date': '2021-08-15',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Yom Kippur',
#    'holiday_date': '2021-09-16',
#    'type_observance': 'Optional holiday'},
#   {'holiday_name': 'September Equinox',
#    'holiday_date': '2021-09-22T21:21:10+02:00',
#    'type_observance': 'Season'},
#   {'holiday_name': "Saint Rupert's Day",
#    'holiday_date': '2021-09-24',
#    'type_observance': 'Local holiday'},
#   {'holiday_name': 'European Heritage Days',
#    'holiday_date': '2021-09-26',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'Plebiscite Day',
#    'holiday_date': '2021-10-10',
#    'type_observance': 'Local holiday'},
#   {'holiday_name': 'National Day',
#    'holiday_date': '2021-10-26',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Daylight Saving Time ends',
#    'holiday_date': '2021-10-31T03:00:00+02:00',
#    'type_observance': 'Clock change/Daylight Saving Time'},
#   {'holiday_name': 'Reformation Day',
#    'holiday_date': '2021-10-31',
#    'type_observance': 'Observance'},
#   {'holiday_name': "All Saints' Day",
#    'holiday_date': '2021-11-01',
#    'type_observance': 'National holiday'},
#   {'holiday_name': "All Souls' Day",
#    'holiday_date': '2021-11-02',
#    'type_observance': 'Observance'},
#   {'holiday_name': "Saint Martin's Day",
#    'holiday_date': '2021-11-11',
#    'type_observance': 'Local holiday'},
#   {'holiday_name': "Saint Leopold's Day",
#    'holiday_date': '2021-11-15',
#    'type_observance': 'Local holiday'},
#   {'holiday_name': 'First Advent Sunday',
#    'holiday_date': '2021-11-28',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'Immaculate Conception',
#    'holiday_date': '2021-12-08',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'December Solstice',
#    'holiday_date': '2021-12-21T16:59:17+01:00',
#    'type_observance': 'Season'},
#   {'holiday_name': 'Christmas Eve',
#    'holiday_date': '2021-12-24',
#    'type_observance': 'Half-day holiday'},
#   {'holiday_name': 'Christmas Day',
#    'holiday_date': '2021-12-25',
#    'type_observance': 'National holiday'},
#   {'holiday_name': "St. Stephen's Day",
# ...
#   {'holiday_name': 'Independence Day',
#    'holiday_date': '2021-07-05',
#    'type_observance': 'National holiday'},
#   {'holiday_name': "Simón Bolívar's Birthday",
#    'holiday_date': '2021-07-24',
#    'type_observance': 'National holiday'},
#   {'holiday_name': "Flag's Day",
#    'holiday_date': '2021-08-03',
#    'type_observance': 'Observance'},
#   {'holiday_name': "National Guard's Day",
#    'holiday_date': '2021-08-04',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'Our Lady of Coromoto',
#    'holiday_date': '2021-09-11',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'September Equinox',
#    'holiday_date': '2021-09-22T15:21:10-04:00',
#    'type_observance': 'Season'},
#   {'holiday_name': "Indigenous Resistance's Day",
#    'holiday_date': '2021-10-12',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'All Saints Day',
#    'holiday_date': '2021-11-01',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'All Souls Day',
#    'holiday_date': '2021-11-02',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'Aviation Day',
#    'holiday_date': '2021-11-27',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'Feast of the Immaculate Conception',
#    'holiday_date': '2021-12-08',
#    'type_observance': 'Common local holiday'},
#   {'holiday_name': 'December Solstice',
#    'holiday_date': '2021-12-21T11:59:17-04:00',
#    'type_observance': 'Season'},
#   {'holiday_name': 'Christmas Eve',
#    'holiday_date': '2021-12-24',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Christmas Day',
#    'holiday_date': '2021-12-25',
#    'type_observance': 'National holiday'},
#   {'holiday_name': "New Year's Eve",
#    'holiday_date': '2021-12-31',
#    'type_observance': 'National holiday'}],
#  'Vietnam': [{'holiday_name': "International New Year's Day",
#    'holiday_date': '2021-01-01',
#    'type_observance': 'National holiday'},
#   {'holiday_name': "Vietnamese New Year's Eve",
#    'holiday_date': '2021-02-11',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Vietnamese New Year',
#    'holiday_date': '2021-02-12',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Tet holiday',
#    'holiday_date': '2021-02-13',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Tet holiday',
#    'holiday_date': '2021-02-14',
#    'type_observance': 'National holiday'},
#   {'holiday_name': "Valentine's Day",
#    'holiday_date': '2021-02-14',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'Tet holiday',
#    'holiday_date': '2021-02-15',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Tet holiday',
#    'holiday_date': '2021-02-16',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'March Equinox',
#    'holiday_date': '2021-03-20T16:37:30+07:00',
#    'type_observance': 'Season'},
#   {'holiday_name': 'Hung Kings Festival',
#    'holiday_date': '2021-04-21',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Liberation Day/Reunification Day',
#    'holiday_date': '2021-04-30',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'International Labor Day',
#    'holiday_date': '2021-05-01',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'International Labor Day observed',
#    'holiday_date': '2021-05-03',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'June Solstice',
#    'holiday_date': '2021-06-21T10:32:08+07:00',
#    'type_observance': 'Season'},
#   {'holiday_name': 'Vietnamese Family Day',
#    'holiday_date': '2021-06-28',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'Independence Day',
#    'holiday_date': '2021-09-02',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'September Equinox',
#    'holiday_date': '2021-09-23T02:21:10+07:00',
#    'type_observance': 'Season'},
#   {'holiday_name': "Vietnamese Women's Day",
#    'holiday_date': '2021-10-20',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'Halloween',
#    'holiday_date': '2021-10-31',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'December Solstice',
#    'holiday_date': '2021-12-21T22:59:17+07:00',
#    'type_observance': 'Season'},
#   {'holiday_name': 'Christmas Eve',
#    'holiday_date': '2021-12-24',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'Christmas Day',
#    'holiday_date': '2021-12-25',
#    'type_observance': 'Observance'},
#   {'holiday_name': "International New Year's Eve",
#    'holiday_date': '2021-12-31',
#    'type_observance': 'Observance'}],
#  'Wallis and Futuna': [{'holiday_name': "New Year's Day",
#    'holiday_date': '2021-01-01',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'March Equinox',
#    'holiday_date': '2021-03-20T21:37:30+12:00',
#    'type_observance': 'Season'},
#   {'holiday_name': 'Easter Monday',
#    'holiday_date': '2021-04-05',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'St. Pierre Chanel Day',
#    'holiday_date': '2021-04-28',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Labor Day / May Day',
#    'holiday_date': '2021-05-01',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Ascension Day',
#    'holiday_date': '2021-05-13',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Whit Monday',
#    'holiday_date': '2021-05-24',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'June Solstice',
#    'holiday_date': '2021-06-21T15:32:08+12:00',
#    'type_observance': 'Season'},
#   {'holiday_name': 'Bastille Day',
#    'holiday_date': '2021-07-14',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Territory Day',
#    'holiday_date': '2021-07-29',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Assumption of Mary',
#    'holiday_date': '2021-08-15',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'September Equinox',
#    'holiday_date': '2021-09-23T07:21:10+12:00',
#    'type_observance': 'Season'},
#   {'holiday_name': "All Saints' Day",
#    'holiday_date': '2021-11-01',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Armistice Day',
#    'holiday_date': '2021-11-11',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'December Solstice',
#    'holiday_date': '2021-12-22T03:59:17+12:00',
#    'type_observance': 'Season'},
#   {'holiday_name': 'Christmas Day',
#    'holiday_date': '2021-12-25',
#    'type_observance': 'National holiday'}],
#  'Yemen': [{'holiday_name': "Isra and Mi'raj",
#    'holiday_date': '2021-03-11',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'March Equinox',
#    'holiday_date': '2021-03-20T12:37:30+03:00',
#    'type_observance': 'Season'},
#   {'holiday_name': 'May Day',
#    'holiday_date': '2021-05-01',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Eid al-Fitr holiday',
#    'holiday_date': '2021-05-11',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Eid al-Fitr Eve',
#    'holiday_date': '2021-05-12',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Eid al-Fitr',
#    'holiday_date': '2021-05-13',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Eid al-Fitr holiday',
#    'holiday_date': '2021-05-14',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Unity Day',
#    'holiday_date': '2021-05-22',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'June Solstice',
#    'holiday_date': '2021-06-21T06:32:08+03:00',
#    'type_observance': 'Season'},
#   {'holiday_name': 'July 7th Anniversary',
#    'holiday_date': '2021-07-07',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'Eid al-Adha Eve',
#    'holiday_date': '2021-07-19',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Eid al-Adha',
#    'holiday_date': '2021-07-20',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Eid al-Adha holiday',
#    'holiday_date': '2021-07-21',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Eid al-Adha holiday',
#    'holiday_date': '2021-07-22',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Eid al-Adha holiday',
#    'holiday_date': '2021-07-23',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Muharram',
#    'holiday_date': '2021-08-10',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'September Equinox',
#    'holiday_date': '2021-09-22T22:21:10+03:00',
#    'type_observance': 'Season'},
#   {'holiday_name': 'Revolution Day',
#    'holiday_date': '2021-09-26',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Liberation Day',
#    'holiday_date': '2021-10-14',
#    'type_observance': 'National holiday'},
#   {'holiday_name': "The Prophet's Birthday",
#    'holiday_date': '2021-10-19',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'Independence Day',
#    'holiday_date': '2021-11-30',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'December Solstice',
#    'holiday_date': '2021-12-21T18:59:17+03:00',
#    'type_observance': 'Season'}],
#  'Zambia': [{'holiday_name': 'New Year',
#    'holiday_date': '2021-01-01',
#    'type_observance': 'National holiday'},
#   {'holiday_name': "International Women's Day",
#    'holiday_date': '2021-03-08',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Youth Day',
#    'holiday_date': '2021-03-12',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'March Equinox',
#    'holiday_date': '2021-03-20T11:37:30+02:00',
#    'type_observance': 'Season'},
#   {'holiday_name': 'Good Friday',
#    'holiday_date': '2021-04-02',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Holy Saturday',
#    'holiday_date': '2021-04-03',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Easter Sunday',
#    'holiday_date': '2021-04-04',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'Easter Monday',
#    'holiday_date': '2021-04-05',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Labour Day',
#    'holiday_date': '2021-05-01',
#    'type_observance': 'National holiday'},
#   {'holiday_name': "Mother's Day",
#    'holiday_date': '2021-05-09',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'Africa Freedom Day',
#    'holiday_date': '2021-05-25',
#    'type_observance': 'National holiday'},
#   {'holiday_name': "Father's Day",
#    'holiday_date': '2021-06-20',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'June Solstice',
#    'holiday_date': '2021-06-21T05:32:08+02:00',
#    'type_observance': 'Season'},
#   {'holiday_name': "Heroes' Day",
#    'holiday_date': '2021-07-05',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Unity Day',
#    'holiday_date': '2021-07-06',
#    'type_observance': 'National holiday'},
#   {'holiday_name': "Farmers' Day",
#    'holiday_date': '2021-08-02',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'September Equinox',
#    'holiday_date': '2021-09-22T21:21:10+02:00',
#    'type_observance': 'Season'},
#   {'holiday_name': 'Prayer Day',
#    'holiday_date': '2021-10-18',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Independence Day',
#    'holiday_date': '2021-10-24',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Day off for Independence Day',
#    'holiday_date': '2021-10-25',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'December Solstice',
#    'holiday_date': '2021-12-21T17:59:17+02:00',
#    'type_observance': 'Season'},
#   {'holiday_name': 'Christmas Day',
#    'holiday_date': '2021-12-25',
#    'type_observance': 'National holiday'}],
#  'Zimbabwe': [{'holiday_name': 'New Year',
#    'holiday_date': '2021-01-01',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Robert Gabriel Mugabe National Youth Day',
#    'holiday_date': '2021-02-21',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Robert Gabriel Mugabe National Youth Day observed',
#    'holiday_date': '2021-02-22',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'March Equinox',
#    'holiday_date': '2021-03-20T11:37:30+02:00',
#    'type_observance': 'Season'},
#   {'holiday_name': 'Good Friday',
#    'holiday_date': '2021-04-02',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Holy Saturday',
#    'holiday_date': '2021-04-03',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Easter Sunday',
#    'holiday_date': '2021-04-04',
#    'type_observance': 'Common local holiday'},
#   {'holiday_name': 'Easter Monday',
#    'holiday_date': '2021-04-05',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Independence Day',
#    'holiday_date': '2021-04-18',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Independence Day observed',
#    'holiday_date': '2021-04-19',
#    'type_observance': 'National holiday'},
#   {'holiday_name': "Workers' Day",
#    'holiday_date': '2021-05-01',
#    'type_observance': 'National holiday'},
#   {'holiday_name': "Mother's Day",
#    'holiday_date': '2021-05-09',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'Africa Day',
#    'holiday_date': '2021-05-25',
#    'type_observance': 'National holiday'},
#   {'holiday_name': "Father's Day",
#    'holiday_date': '2021-06-20',
#    'type_observance': 'Observance'},
#   {'holiday_name': 'June Solstice',
#    'holiday_date': '2021-06-21T05:32:08+02:00',
#    'type_observance': 'Season'},
#   {'holiday_name': "Heroes' Day",
#    'holiday_date': '2021-08-09',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Defence Forces Day',
#    'holiday_date': '2021-08-10',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'September Equinox',
#    'holiday_date': '2021-09-22T21:21:10+02:00',
#    'type_observance': 'Season'},
#   {'holiday_name': 'December Solstice',
#    'holiday_date': '2021-12-21T17:59:17+02:00',
#    'type_observance': 'Season'},
#   {'holiday_name': 'Unity Day',
#    'holiday_date': '2021-12-22',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Christmas Day',
#    'holiday_date': '2021-12-25',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Boxing Day',
#    'holiday_date': '2021-12-26',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Boxing Day observed',
#    'holiday_date': '2021-12-27',
#    'type_observance': 'National holiday'}],
#  'eSwatini': [{'holiday_name': 'New Year',
#    'holiday_date': '2021-01-01',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'March Equinox',
#    'holiday_date': '2021-03-20T11:37:30+02:00',
#    'type_observance': 'Season'},
#   {'holiday_name': 'Good Friday',
#    'holiday_date': '2021-04-02',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Easter Monday',
#    'holiday_date': '2021-04-05',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Birthday of King Mswati III',
#    'holiday_date': '2021-04-19',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'National Flag Day',
#    'holiday_date': '2021-04-25',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'May Day',
#    'holiday_date': '2021-05-01',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Ascension Day',
#    'holiday_date': '2021-05-13',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'June Solstice',
#    'holiday_date': '2021-06-21T05:32:08+02:00',
#    'type_observance': 'Season'},
#   {'holiday_name': 'Birthday of the late King Sobhuza',
#    'holiday_date': '2021-07-22',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Umhlanga Reed Dance',
#    'holiday_date': '2021-09-06',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Somhlolo Day (Independence Day)',
#    'holiday_date': '2021-09-06',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'September Equinox',
#    'holiday_date': '2021-09-22T21:21:10+02:00',
#    'type_observance': 'Season'},
#   {'holiday_name': 'December Solstice',
#    'holiday_date': '2021-12-21T17:59:17+02:00',
#    'type_observance': 'Season'},
#   {'holiday_name': 'Christmas Day',
#    'holiday_date': '2021-12-25',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Boxing Day',
#    'holiday_date': '2021-12-26',
#    'type_observance': 'National holiday'},
#   {'holiday_name': 'Incwala Day',
#    'holiday_date': '2021-12-28',
#    'type_observance': 'National holiday'}]}
